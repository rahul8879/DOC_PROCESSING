# %%
from fastapi import FastAPI, File, UploadFile
import pytesseract
from PIL import Image
import io
from transformers import pipeline
import torch
from transformers import logging

# %%
from langchain_community.document_loaders.image import UnstructuredImageLoader

# %%
loader = UnstructuredImageLoader(
    "sample_2png")

# %%
data = loader.load()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data = loader.load()
#
# File c:\Users\Rahul\Documents\FREELANCING\1.AppliedSkil\LLM_Project\KYC_DOC\kyc-env\Lib\site-packages\langchain_core\document_loaders\base.py:31, in BaseLoader.load(self)
#      29 def load(self) -> list[Document]:
#      30     """Load data into Document objects."""
# ---> 31     return list(self.lazy_load())
#
# File c:\Users\Rahul\Documents\FREELANCING\1.AppliedSkil\LLM_Project\KYC_DOC\kyc-env\Lib\site-packages\langchain_community\document_loaders\unstructured.py:107, in UnstructuredBaseLoader.lazy_load(self)
#     105 def lazy_load(self) -> Iterator[Document]:
#     106     """Load file."""
# --> 107     elements = self._get_elements()
#     108     self._post_process_elements(elements)
#     109     if self.mode == "elements":
#
# File c:\Users\Rahul\Documents\FREELANCING\1.AppliedSkil\LLM_Project\KYC_DOC\kyc-env\Lib\site-packages\langchain_community\document_loaders\image.py:31, in UnstructuredImageLoader._get_elements(self)
#      30 def _get_elements(self) -> List:
# ---> 31     from unstructured.partition.image import partition_image
#      33     return partition_image(filename=self.file_path, **self.unstructured_kwargs)
#
# File c:\Users\Rahul\Documents\FREELANCING\1.AppliedSkil\LLM_Project\KYC_DOC\kyc-env\Lib\site-packages\unstructured\partition\image.py:10
#       8 from unstructured.partition.common.common import exactly_one
#       9 from unstructured.partition.common.lang import check_language_args
# ---> 10 from unstructured.partition.pdf import partition_pdf_or_image
#      11 from unstructured.partition.utils.constants import PartitionStrategy
#      14 @process_metadata()
#      15 @add_metadata
#      16 @add_chunking_strategy
#    (...)
#      35     **kwargs: Any,
#      36 ) -> list[Element]:
#
# File c:\Users\Rahul\Documents\FREELANCING\1.AppliedSkil\LLM_Project\KYC_DOC\kyc-env\Lib\site-packages\unstructured\partition\pdf.py:57
#      51 from unstructured.partition.common.lang import (
#      52     check_language_args,
#      53     prepare_languages_for_tesseract,
#      54     tesseract_to_paddle_language,
#      55 )
#      56 from unstructured.partition.common.metadata import get_last_modified_date
# ---> 57 from unstructured.partition.pdf_image.analysis.layout_dump import (
#      58     ExtractedLayoutDumper,
#      59     FinalLayoutDumper,
#      60     ObjectDetectionLayoutDumper,
#      61     OCRLayoutDumper,
#      62 )
#      63 from unstructured.partition.pdf_image.analysis.tools import save_analysis_artifiacts
#      64 from unstructured.partition.pdf_image.form_extraction import run_form_extraction
#
# File c:\Users\Rahul\Documents\FREELANCING\1.AppliedSkil\LLM_Project\KYC_DOC\kyc-env\Lib\site-packages\unstructured\partition\pdf_image\analysis\layout_dump.py:8
#       5 from typing import List, Optional
#       7 from unstructured_inference.inference.elements import ImageTextRegion, TextRegion
# ----> 8 from unstructured_inference.inference.layout import DocumentLayout
#       9 from unstructured_inference.models.base import get_model
#      10 from unstructured_inference.models.detectron2onnx import (
#      11     DEFAULT_LABEL_MAP as DETECTRON_LABEL_MAP,
#      12 )
#
# File c:\Users\Rahul\Documents\FREELANCING\1.AppliedSkil\LLM_Project\KYC_DOC\kyc-env\Lib\site-packages\unstructured_inference\inference\layout.py:19
#      15 from unstructured_inference.inference.layoutelement import (
#      16     LayoutElement,
#      17 )
#      18 from unstructured_inference.logger import logger
# ---> 19 from unstructured_inference.models.base import get_model
#      20 from unstructured_inference.models.unstructuredmodel import (
#      21     UnstructuredElementExtractionModel,
#      22     UnstructuredObjectDetectionModel,
#      23 )
#      24 from unstructured_inference.visualize import draw_bbox
#
# File c:\Users\Rahul\Documents\FREELANCING\1.AppliedSkil\LLM_Project\KYC_DOC\kyc-env\Lib\site-packages\unstructured_inference\models\base.py:9
#       7 from unstructured_inference.models.chipper import MODEL_TYPES as CHIPPER_MODEL_TYPES
#       8 from unstructured_inference.models.chipper import UnstructuredChipperModel
# ----> 9 from unstructured_inference.models.detectron2onnx import MODEL_TYPES as DETECTRON2_ONNX_MODEL_TYPES
#      10 from unstructured_inference.models.detectron2onnx import UnstructuredDetectronONNXModel
#      11 from unstructured_inference.models.unstructuredmodel import UnstructuredModel
#
# File c:\Users\Rahul\Documents\FREELANCING\1.AppliedSkil\LLM_Project\KYC_DOC\kyc-env\Lib\site-packages\unstructured_inference\models\detectron2onnx.py:9
#       7 from huggingface_hub.constants import HUGGINGFACE_HUB_CACHE
#       8 from onnxruntime.capi import _pybind_state as C
# ----> 9 from onnxruntime.quantization import QuantType, quantize_dynamic
#      10 from PIL import Image
#      12 from unstructured_inference.constants import Source
#
# File c:\Users\Rahul\Documents\FREELANCING\1.AppliedSkil\LLM_Project\KYC_DOC\kyc-env\Lib\site-packages\onnxruntime\quantization\__init__.py:1
# ----> 1 from .calibrate import (  # noqa: F401
#       2     CalibraterBase,
#       3     CalibrationDataReader,
#       4     CalibrationMethod,
#       5     MinMaxCalibrater,
#       6     create_calibrator,
#       7 )
#       8 from .qdq_quantizer import QDQQuantizer  # noqa: F401
#       9 from .quant_utils import QuantFormat, QuantType, write_calibration_table  # noqa: F401
#
# File c:\Users\Rahul\Documents\FREELANCING\1.AppliedSkil\LLM_Project\KYC_DOC\kyc-env\Lib\site-packages\onnxruntime\quantization\calibrate.py:17
#      14 from typing import Dict, Optional, Sequence, Tuple, Union
#      16 import numpy as np
# ---> 17 import onnx
#      18 from onnx import ModelProto, TensorProto, helper, numpy_helper
#      20 import onnxruntime
#
# File c:\Users\Rahul\Documents\FREELANCING\1.AppliedSkil\LLM_Project\KYC_DOC\kyc-env\Lib\site-packages\onnx\__init__.py:77
#      73 from typing import IO, Literal, Union
#      76 from onnx import serialization
# ---> 77 from onnx.onnx_cpp2py_export import ONNX_ML
#      78 from onnx.external_data_helper import (
#      79     load_external_data_for_model,
#      80     write_external_data_tensors,
#      81     convert_model_to_external_data,
#      82 )
#      83 from onnx.onnx_pb import (
#      84     AttributeProto,
#      85     EXPERIMENTAL,
#    (...)
#     111     Version,
#     112 )
#
# ImportError: DLL load failed while importing onnx_cpp2py_export: A dynamic link library (DLL) initialization routine failed.
